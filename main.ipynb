# %%
from data.eurosat import load_eurosat
from models.mlp import NeuralNetwork
from train.trainer import Trainer
from utils.plot import plot_all

import os

# ===== 创建目录 =====
os.makedirs("outputs", exist_ok=True)
os.makedirs("logs", exist_ok=True)

# ===== 加载数据 =====
(X_train, y_train), (X_val, y_val), _ = load_eurosat("data/EuroSAT_RGB")
# Out:
# 数据加载完成: (27000, 12288), 类别数: 10

# %%
# ===== 初始化模型 =====
model = NeuralNetwork(
    input_dim=X_train.shape[1],
    hidden_dim1=1024,
    hidden_dim2=512,
    output_dim=10
)

# ===== 初始化 Trainer =====
trainer = Trainer(
    model,
    lr=0.1,
    reg=1e-4,
    step_size=15,   # 学习率衰减
    gamma=0.5,
    save_path="outputs/best_model_1.npz"
)

# ===== 训练 =====
history = trainer.train(
    X_train,
    y_train,
    X_val,
    y_val,
    epochs=50,
    batch_size=64,
    verbose=True
)

# =====================================================
# ✅ 1️⃣ 保存训练日志（模拟grid search的log格式）
# =====================================================
log_path = "logs/lr0.1_h1024_512_reg0.0001_epoch50.txt"

with open(log_path, "w") as f:
    f.write("epoch,train_loss,train_acc,val_loss,val_acc\n")

    for i in range(len(history["train_losses"])):
        f.write(
            f"{i+1},"
            f"{history['train_losses'][i]},"
            f"{history['train_accs'][i]},"
            f"{history['val_losses'][i]},"
            f"{history['val_accs'][i]}\n"
        )

print(f"\n训练日志已保存到: {log_path}")

# =====================================================
# ✅ 2️⃣ 绘制四张曲线（检查plot是否正确）
# =====================================================
plot_all(trainer, save_path="outputs/1_lr0.1_h1024_512_reg1e-4_curve.png", show=False)

# =====================================================
# ✅ 3️⃣ 打印最佳结果
# =====================================================
print("\n===== Training Finished =====")
print(f"Best Validation Accuracy: {trainer.best_val_acc:.4f}")
# Out:
# Epoch 1/50 | Train Loss: 1.7391 | Train Acc: 0.4244 | Val Loss: 1.5501 | Val Acc: 0.5189
# Epoch 2/50 | Train Loss: 1.4114 | Train Acc: 0.5588 | Val Loss: 1.3688 | Val Acc: 0.5741
# Epoch 3/50 | Train Loss: 1.2665 | Train Acc: 0.6116 | Val Loss: 1.2781 | Val Acc: 0.5978
# Epoch 4/50 | Train Loss: 1.1817 | Train Acc: 0.6384 | Val Loss: 1.2422 | Val Acc: 0.5993
# Epoch 5/50 | Train Loss: 1.1181 | Train Acc: 0.6587 | Val Loss: 1.2012 | Val Acc: 0.6041
# Epoch 6/50 | Train Loss: 1.0566 | Train Acc: 0.6829 | Val Loss: 1.1563 | Val Acc: 0.6185
# Epoch 7/50 | Train Loss: 1.0172 | Train Acc: 0.6939 | Val Loss: 1.1335 | Val Acc: 0.6293
# Epoch 8/50 | Train Loss: 0.9757 | Train Acc: 0.7071 | Val Loss: 1.1079 | Val Acc: 0.6511
# Epoch 9/50 | Train Loss: 0.9347 | Train Acc: 0.7231 | Val Loss: 1.1336 | Val Acc: 0.6441
# Epoch 10/50 | Train Loss: 0.9083 | Train Acc: 0.7271 | Val Loss: 1.0788 | Val Acc: 0.6507
# Epoch 11/50 | Train Loss: 0.8822 | Train Acc: 0.7364 | Val Loss: 1.1958 | Val Acc: 0.6004
# Epoch 12/50 | Train Loss: 0.8562 | Train Acc: 0.7438 | Val Loss: 1.0496 | Val Acc: 0.6504
# Epoch 13/50 | Train Loss: 0.8380 | Train Acc: 0.7483 | Val Loss: 1.0678 | Val Acc: 0.6481
# Epoch 14/50 | Train Loss: 0.8124 | Train Acc: 0.7562 | Val Loss: 1.0224 | Val Acc: 0.6533
# [LR Decay] New LR = 0.050000
# Epoch 15/50 | Train Loss: 0.7455 | Train Acc: 0.7827 | Val Loss: 0.9805 | Val Acc: 0.6633
# Epoch 16/50 | Train Loss: 0.7219 | Train Acc: 0.7902 | Val Loss: 1.0091 | Val Acc: 0.6611
# Epoch 17/50 | Train Loss: 0.7117 | Train Acc: 0.7957 | Val Loss: 1.0067 | Val Acc: 0.6593
# Epoch 18/50 | Train Loss: 0.7029 | Train Acc: 0.7983 | Val Loss: 1.0038 | Val Acc: 0.6648
# Epoch 19/50 | Train Loss: 0.6974 | Train Acc: 0.7961 | Val Loss: 0.9941 | Val Acc: 0.6719
# Epoch 20/50 | Train Loss: 0.6757 | Train Acc: 0.8054 | Val Loss: 0.9551 | Val Acc: 0.6730
# Epoch 21/50 | Train Loss: 0.6671 | Train Acc: 0.8076 | Val Loss: 0.9888 | Val Acc: 0.6678
# Epoch 22/50 | Train Loss: 0.6628 | Train Acc: 0.8115 | Val Loss: 0.9568 | Val Acc: 0.6841
# Epoch 23/50 | Train Loss: 0.6474 | Train Acc: 0.8149 | Val Loss: 0.9530 | Val Acc: 0.6819
# Epoch 24/50 | Train Loss: 0.6425 | Train Acc: 0.8175 | Val Loss: 0.9510 | Val Acc: 0.6811
# Epoch 25/50 | Train Loss: 0.6325 | Train Acc: 0.8200 | Val Loss: 0.9679 | Val Acc: 0.6752
# Epoch 26/50 | Train Loss: 0.6235 | Train Acc: 0.8202 | Val Loss: 0.9731 | Val Acc: 0.6696
# Epoch 27/50 | Train Loss: 0.6146 | Train Acc: 0.8279 | Val Loss: 1.0034 | Val Acc: 0.6644
# Epoch 28/50 | Train Loss: 0.6054 | Train Acc: 0.8273 | Val Loss: 0.9463 | Val Acc: 0.6756
# Epoch 29/50 | Train Loss: 0.5975 | Train Acc: 0.8300 | Val Loss: 0.9667 | Val Acc: 0.6807
# [LR Decay] New LR = 0.025000
# Epoch 30/50 | Train Loss: 0.5647 | Train Acc: 0.8450 | Val Loss: 0.9284 | Val Acc: 0.6878
# Epoch 31/50 | Train Loss: 0.5575 | Train Acc: 0.8486 | Val Loss: 0.9257 | Val Acc: 0.6881
# Epoch 32/50 | Train Loss: 0.5582 | Train Acc: 0.8451 | Val Loss: 0.9504 | Val Acc: 0.6785
# Epoch 33/50 | Train Loss: 0.5513 | Train Acc: 0.8502 | Val Loss: 0.9341 | Val Acc: 0.6796
# Epoch 34/50 | Train Loss: 0.5475 | Train Acc: 0.8512 | Val Loss: 0.9214 | Val Acc: 0.6885
# Epoch 35/50 | Train Loss: 0.5414 | Train Acc: 0.8538 | Val Loss: 0.9389 | Val Acc: 0.6819
# Epoch 36/50 | Train Loss: 0.5366 | Train Acc: 0.8545 | Val Loss: 0.9152 | Val Acc: 0.6893
# Epoch 37/50 | Train Loss: 0.5351 | Train Acc: 0.8562 | Val Loss: 0.9257 | Val Acc: 0.6785
# Epoch 38/50 | Train Loss: 0.5292 | Train Acc: 0.8594 | Val Loss: 0.9232 | Val Acc: 0.6885
# Epoch 39/50 | Train Loss: 0.5228 | Train Acc: 0.8614 | Val Loss: 0.9251 | Val Acc: 0.6881
# Epoch 40/50 | Train Loss: 0.5211 | Train Acc: 0.8616 | Val Loss: 0.9384 | Val Acc: 0.6807
# Epoch 41/50 | Train Loss: 0.5177 | Train Acc: 0.8615 | Val Loss: 0.9178 | Val Acc: 0.6885
# Epoch 42/50 | Train Loss: 0.5149 | Train Acc: 0.8611 | Val Loss: 0.9227 | Val Acc: 0.6852
# Epoch 43/50 | Train Loss: 0.5095 | Train Acc: 0.8631 | Val Loss: 0.9330 | Val Acc: 0.6885
# Epoch 44/50 | Train Loss: 0.5079 | Train Acc: 0.8638 | Val Loss: 0.9250 | Val Acc: 0.6859
# [LR Decay] New LR = 0.012500
# Epoch 45/50 | Train Loss: 0.4903 | Train Acc: 0.8710 | Val Loss: 0.9161 | Val Acc: 0.6852
# Epoch 46/50 | Train Loss: 0.4878 | Train Acc: 0.8719 | Val Loss: 0.9241 | Val Acc: 0.6863
# Early stopping triggered
#
# 训练日志已保存到: logs/lr0.1_h1024_512_reg0.0001_epoch50.txt
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 52
#      47 print(f"\n训练日志已保存到: {log_path}")
#      49 # =====================================================
#      50 # ✅ 2️⃣ 绘制四张曲线（检查plot是否正确）
#      51 # =====================================================
# ---> 52 plot_all(trainer, save_path="outputs/1_lr0.1_h1024_512_reg1e-4_curve.png", show=False)
#      54 # =====================================================
#      55 # ✅ 3️⃣ 打印最佳结果
#      56 # =====================================================
#      57 print("\n===== Training Finished =====")
#
# TypeError: plot_all() got an unexpected keyword argument 'save_path'

# %%
# ===== 初始化模型 =====
model = NeuralNetwork(
    input_dim=X_train.shape[1],
    hidden_dim1=1024,
    hidden_dim2=512,
    output_dim=10
)

# ===== 初始化 Trainer =====
trainer = Trainer(
    model,
    lr=0.1,
    reg=1e-4,
    step_size=10,   # 学习率衰减
    gamma=0.5,
    save_path="outputs/best_model_2.npz"
)

# ===== 训练 =====
history = trainer.train(
    X_train,
    y_train,
    X_val,
    y_val,
    epochs=50,
    batch_size=64,
    verbose=True
)

# =====================================================
# ✅ 1️⃣ 保存训练日志（模拟grid search的log格式）
# =====================================================
log_path = "logs/lr0.1_h1024_512_reg0.0001_epoch50_2.txt"

with open(log_path, "w") as f:
    f.write("epoch,train_loss,train_acc,val_loss,val_acc\n")

    for i in range(len(history["train_losses"])):
        f.write(
            f"{i+1},"
            f"{history['train_losses'][i]},"
            f"{history['train_accs'][i]},"
            f"{history['val_losses'][i]},"
            f"{history['val_accs'][i]}\n"
        )

print(f"\n训练日志已保存到: {log_path}")

# =====================================================
# ✅ 2️⃣ 绘制四张曲线（检查plot是否正确）
# =====================================================
plot_all(trainer, save_path="outputs/2_lr0.1_h1024_512_reg1e-4_curve.png", show=False)

# =====================================================
# ✅ 3️⃣ 打印最佳结果
# =====================================================
print("\n===== Training Finished =====")
print(f"Best Validation Accuracy: {trainer.best_val_acc:.4f}")
# Out:
# Epoch 1/50 | Train Loss: 1.7246 | Train Acc: 0.4327 | Val Loss: 1.5554 | Val Acc: 0.5174
# Epoch 2/50 | Train Loss: 1.4144 | Train Acc: 0.5607 | Val Loss: 1.3885 | Val Acc: 0.5600
# Epoch 3/50 | Train Loss: 1.2749 | Train Acc: 0.6097 | Val Loss: 1.2898 | Val Acc: 0.5948
# Epoch 4/50 | Train Loss: 1.1896 | Train Acc: 0.6388 | Val Loss: 1.2473 | Val Acc: 0.6056
# Epoch 5/50 | Train Loss: 1.1258 | Train Acc: 0.6559 | Val Loss: 1.2033 | Val Acc: 0.6163
# Epoch 6/50 | Train Loss: 1.0699 | Train Acc: 0.6800 | Val Loss: 1.1666 | Val Acc: 0.6193
# Epoch 7/50 | Train Loss: 1.0251 | Train Acc: 0.6902 | Val Loss: 1.1424 | Val Acc: 0.6311
# Epoch 8/50 | Train Loss: 0.9847 | Train Acc: 0.7029 | Val Loss: 1.1055 | Val Acc: 0.6541
# Epoch 9/50 | Train Loss: 0.9421 | Train Acc: 0.7205 | Val Loss: 1.1435 | Val Acc: 0.6459
# [LR Decay] New LR = 0.050000
# Epoch 10/50 | Train Loss: 0.8804 | Train Acc: 0.7425 | Val Loss: 1.0566 | Val Acc: 0.6533
# Epoch 11/50 | Train Loss: 0.8474 | Train Acc: 0.7528 | Val Loss: 1.0311 | Val Acc: 0.6630
# Epoch 12/50 | Train Loss: 0.8332 | Train Acc: 0.7578 | Val Loss: 1.0270 | Val Acc: 0.6607
# Epoch 13/50 | Train Loss: 0.8163 | Train Acc: 0.7619 | Val Loss: 1.0272 | Val Acc: 0.6626
# Epoch 14/50 | Train Loss: 0.8021 | Train Acc: 0.7681 | Val Loss: 1.0144 | Val Acc: 0.6619
# Epoch 15/50 | Train Loss: 0.7866 | Train Acc: 0.7740 | Val Loss: 1.0079 | Val Acc: 0.6689
# Epoch 16/50 | Train Loss: 0.7714 | Train Acc: 0.7768 | Val Loss: 1.0327 | Val Acc: 0.6596
# Epoch 17/50 | Train Loss: 0.7604 | Train Acc: 0.7818 | Val Loss: 1.0202 | Val Acc: 0.6622
# Epoch 18/50 | Train Loss: 0.7515 | Train Acc: 0.7836 | Val Loss: 1.0188 | Val Acc: 0.6637
# Epoch 19/50 | Train Loss: 0.7445 | Train Acc: 0.7831 | Val Loss: 1.0100 | Val Acc: 0.6637
# [LR Decay] New LR = 0.025000
# Epoch 20/50 | Train Loss: 0.7001 | Train Acc: 0.8038 | Val Loss: 0.9795 | Val Acc: 0.6748
# Epoch 21/50 | Train Loss: 0.6889 | Train Acc: 0.8080 | Val Loss: 0.9885 | Val Acc: 0.6737
# Epoch 22/50 | Train Loss: 0.6852 | Train Acc: 0.8081 | Val Loss: 0.9626 | Val Acc: 0.6789
# Epoch 23/50 | Train Loss: 0.6777 | Train Acc: 0.8102 | Val Loss: 0.9676 | Val Acc: 0.6770
# Epoch 24/50 | Train Loss: 0.6737 | Train Acc: 0.8104 | Val Loss: 0.9592 | Val Acc: 0.6867
# Epoch 25/50 | Train Loss: 0.6658 | Train Acc: 0.8141 | Val Loss: 0.9666 | Val Acc: 0.6752
# Epoch 26/50 | Train Loss: 0.6601 | Train Acc: 0.8186 | Val Loss: 0.9555 | Val Acc: 0.6844
# Epoch 27/50 | Train Loss: 0.6548 | Train Acc: 0.8194 | Val Loss: 0.9605 | Val Acc: 0.6807
# Epoch 28/50 | Train Loss: 0.6461 | Train Acc: 0.8214 | Val Loss: 0.9559 | Val Acc: 0.6781
# Epoch 29/50 | Train Loss: 0.6411 | Train Acc: 0.8228 | Val Loss: 0.9727 | Val Acc: 0.6744
# [LR Decay] New LR = 0.012500
# Epoch 30/50 | Train Loss: 0.6247 | Train Acc: 0.8305 | Val Loss: 0.9434 | Val Acc: 0.6870
# Epoch 31/50 | Train Loss: 0.6208 | Train Acc: 0.8315 | Val Loss: 0.9406 | Val Acc: 0.6852
# Epoch 32/50 | Train Loss: 0.6198 | Train Acc: 0.8317 | Val Loss: 0.9447 | Val Acc: 0.6867
# Epoch 33/50 | Train Loss: 0.6158 | Train Acc: 0.8325 | Val Loss: 0.9525 | Val Acc: 0.6807
# Epoch 34/50 | Train Loss: 0.6128 | Train Acc: 0.8330 | Val Loss: 0.9510 | Val Acc: 0.6807
# Epoch 35/50 | Train Loss: 0.6095 | Train Acc: 0.8337 | Val Loss: 0.9420 | Val Acc: 0.6804
# Epoch 36/50 | Train Loss: 0.6058 | Train Acc: 0.8354 | Val Loss: 0.9391 | Val Acc: 0.6833
# Epoch 37/50 | Train Loss: 0.6043 | Train Acc: 0.8373 | Val Loss: 0.9406 | Val Acc: 0.6807
# Epoch 38/50 | Train Loss: 0.6013 | Train Acc: 0.8370 | Val Loss: 0.9392 | Val Acc: 0.6830
# Epoch 39/50 | Train Loss: 0.5978 | Train Acc: 0.8385 | Val Loss: 0.9353 | Val Acc: 0.6874
# [LR Decay] New LR = 0.006250
# Epoch 40/50 | Train Loss: 0.5903 | Train Acc: 0.8438 | Val Loss: 0.9340 | Val Acc: 0.6856
# Epoch 41/50 | Train Loss: 0.5882 | Train Acc: 0.8409 | Val Loss: 0.9323 | Val Acc: 0.6852
# Epoch 42/50 | Train Loss: 0.5869 | Train Acc: 0.8436 | Val Loss: 0.9334 | Val Acc: 0.6863
# Epoch 43/50 | Train Loss: 0.5853 | Train Acc: 0.8429 | Val Loss: 0.9377 | Val Acc: 0.6830
# Epoch 44/50 | Train Loss: 0.5834 | Train Acc: 0.8447 | Val Loss: 0.9335 | Val Acc: 0.6893
# Epoch 45/50 | Train Loss: 0.5819 | Train Acc: 0.8435 | Val Loss: 0.9332 | Val Acc: 0.6830
# Epoch 46/50 | Train Loss: 0.5806 | Train Acc: 0.8450 | Val Loss: 0.9313 | Val Acc: 0.6848
# Epoch 47/50 | Train Loss: 0.5793 | Train Acc: 0.8463 | Val Loss: 0.9340 | Val Acc: 0.6852
# Epoch 48/50 | Train Loss: 0.5784 | Train Acc: 0.8466 | Val Loss: 0.9368 | Val Acc: 0.6867
# Epoch 49/50 | Train Loss: 0.5767 | Train Acc: 0.8452 | Val Loss: 0.9279 | Val Acc: 0.6904
# [LR Decay] New LR = 0.003125
# Epoch 50/50 | Train Loss: 0.5723 | Train Acc: 0.8480 | Val Loss: 0.9282 | Val Acc: 0.6881
#
# 训练日志已保存到: logs/lr0.1_h1024_512_reg0.0001_epoch50_2.txt
# [SAVE] Curve saved to outputs/2_lr0.1_h1024_512_reg1e-4_curve.png
#
# ===== Training Finished =====
# Best Validation Accuracy: 0.6904
